# %% [markdown]
# <img src="./Logo_UNSAM.png" align="right" width="150" />
#
# #### Análisis y Procesamiento de Señales
#
# # Trabajo Práctico Nº6: Transformada Z y Respuesta en frecuencia
# #### Patricia González Todd
#
# - El objetivo de este trabajo es aplicar los conceptos de transformada Z vistos en clase para ejercitar con los ejercicios dados.
#  Se pide, para cada item:
#
# 1) Hallar T(z)=Y(z)X(z)
# .
# 2) Calcular su respuesta en frecuencia de módulo y fase.
#
# 3) Simular y validar la respuesta en frecuencia de todos los sistemas con Numpy.

# %% [markdown]
# ### a) y(n)=x(n−3)+x(n−2)+x(n−1)+x(n)

# %% [markdown]
# <img src="./ts6_aa.png" width="1500" />

# %% [markdown]
# <img src="./Ts6_a.png" width="1500" />

# %% [markdown]
# ### b) y(n)=x(n−4)+x(n−3)+x(n−2)+x(n−1)+x(n)

# %% [markdown]
# <img src="./ts6_bb.jpg" width="1500" />

# %% [markdown]
# <img src="./Ts6_b.png" width="1500" />

# %% [markdown]
# ### c)  y(n)=x(n)−x(n−1)

# %% [markdown]
# <img src="./ts6_cc.png" width="1500" />

# %% [markdown]
# <img src="./Ts6_c.png" width="1500" />

# %% [markdown]
# ### d)  y(n)=x(n)−x(n−2)

# %% [markdown]
# <img src="./ts6_dd.png" width="1500" />

# %% [markdown]
# <img src="./Ts6_d.png" width="1500" />
